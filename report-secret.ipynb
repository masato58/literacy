# %%
# !printf "26G3071" >report

# %%
# !cat yabuki-public.pem
# Out:
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEA70LrqthUCTjYijUUPkz+
# X8dGTHSazlHx2xwuOPFsmK5rf1QB42kJ5NRTX5KebVbPqLsHT140TmPeS7KJ8Xl3
# Y3PBlyV/XjiacwdVySJHLDVr+iANKMNPiMCIFyB69mKnHMzzOlRX2Io731wEhuPD
# GNO0+UTPZ9OHeF1cbS5WLPKOcGJYAiJmGsCuknZeeMkaFob2jgbXOs09xPgEXHBx
# iax2NZRBumr6fCoRvmKeFHCnNygOMfOyuCrfPt4r5U3O0k26xiVhiWwcxNI1NRmD
# NI1un592nZWycjGaeA82YcswT+gBbF/d2wr6KtKQK0Rq1LUm2BCpkpVN/KlMRYse
# qQIDAQAB
# -----END PUBLIC KEY-----

# %%
# !wget https://raw.githubusercontent.com/taroyabuki/LI/refs/heads/main/yabuki-public.pem
# Out:
# --2026-06-17 05:37:07--  https://raw.githubusercontent.com/taroyabuki/LI/refs/heads/main/yabuki-public.pem
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 451 [text/plain]
# Saving to: ‘yabuki-public.pem.2’
#
# yabuki-public.pem.2 100%[===================>]     451  --.-KB/s    in 0s
#
# 2026-06-17 05:37:07 (5.06 MB/s) - ‘yabuki-public.pem.2’ saved [451/451]

# %%
# !openssl pkeyutl -encrypt -pubin -inkey yabuki-public.pem -in report -out report-secret
# !base64 report-secret
# Out:
# MwUQjXY66Ua+s9oMu/3X5ZKi6XgCsPn8fIMokQFDbCGLy3hEpTKZWqy/Z+Sq0SdxpBTsMl7Ouxjm
# IPbHD3nMthrK0jzA4AhxQcc8QW7GbEJ4UT/YD60hIiklz/tW2o5oJ7eOcghiZXxYK0tH/+EQGeUO
# vPGm2EM8d4cYQjvzOVcUQYiFwgbZole9OfHG9UnH6noBxYiNa1MC8xwMVk5Qsi+UnEiZxzQzsROs
# jbwuzmeaT8FBnNDW34uAlM/VnZOdT2KNk52QJKzQo6IASjPj/XKV3mml8/8OyHpJIbt4jq63OnlQ
# muM42msUbMUocP0KPoKt7WdsdGsIaIO2YSntKQ==

# %%
# !cat report-secret
# Out:
# be|X+KG������C<w�B;�9WA���٢W�9���I��zň�kS�VNP�/��H��43����.�g�O�A���ߋ���՝��Ob����$�У�J3��r��i����zI!�x���:yP��8�kl�(p�
# h��a)�)
